# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

from pylab import rcParams

rcParams['figure.figsize'] = 12,8
plt.rcParams["font.size"] = 18

import scipy as sp
import scipy.stats

# %%
offset = 313.15 - 309.6
v_offset = 0 #.009

# %%
#unknown1 = np.array([
#    # wavelength[nm], V [V], current[mA]
#    [386.5, 0.016],
#    [385.6, 0.015],
#    [386.0, 0.018],
#    [387.0, 0.011],
#    [388.6, 0.009],
#    [443.4, 0.012],
#    [445.7, 0.009],
#    [469.2, 0.010],
#    [481.0, 0.009],
#    [490.0, 0.010],
#    [498.7, 0.014],
#    [501.0, 0.009],
#    [584.8, 0.015],
#    [584.9, 0.023],
#    [585.4, 0.013],
#    [587.2, 0.009],
#    [664.7, 0.018],
#    [665.0, 0.014],
#    [665.5, 0.009],
#    [703.4, 0.014],
#    [703.8, 0.009],
#    [724.3, 0.010],
#    [724.0, 0.009],
#    [775.0, 0.010],
#    [774.6, 0.009],
#    [775.4, 0.009]
#])

unknown1 = np.array([
    # wavelength[nm], V [V], current[mA]
    [50, 0.065],
    [100, 0.085],
    [150, 0.068],
    [246, 0.082],
    [334, 0.079],
    [357.4, 0.126],
    [359, 0.073],
    [367, 0.123],
    [376, 0.070],
    [385.6, 8.025],
    [394.2, 0.592],
    [399.6, 1.047],
    [408.8, 0.243],
    [434.6, 0.414],
    [440.4, 0.102],
    [443, 6.527],
    [443.4, 7.094],
    [468.8, 1.503],
    [585, 9.107],
    [703.8, 6.631],
    [724.6, 2.151],
    [774.8, 1.961]
])

vs = unknown1[:,1] - v_offset
vs /= np.max(vs)

plt.xlim(200, 800)
plt.xlabel("wavelength [nm]")
plt.ylabel("intensity (a.u.)")
plt.scatter(unknown1[:, 0] + offset, vs)

# %%
unknown2 = np.array([
    # wavelength[nm], V [V], current[mA]
    [1, 0.105],
    [73, 0.068],
    [155, 0.065],
    [231, 0.065],
    [302, 0.068],
    [308.4, 0.070],
    [332, 0.110],
    [350, 0.163],
    [379, 0.182],
    
    [404, 0.172],
    [423, 0.148],
    [429.5, 0.243],
    [434.3, 0.150],
    [477.5, 0.121],
    [483.5, 0.392],
    [483.6, 0.642],
    [484.8, 0.175],
    [531, 0.097],
    [599.8, 0.129],
    [650, 0.084],
    [652.8, 2.029],
    [654.2, 0.085],
    [701, 0.083],
    [777, 0.076]
])

vs2 = unknown2[:,1] - v_offset
vs2 /= np.max(vs2)

plt.xlim(200, 800)

plt.xlabel("wavelength [nm]")
plt.ylabel("intensity (a.u.)")
plt.scatter(unknown2[:, 0] + offset, vs2)
plt.show()

#img = mpimg.imread('H2.png')
#plt.imshow(img)

# %%
keikoto = np.array([
    [100, 0.021],
    [151.0, 0.021],
    [200, 0.023],
    [261, 0.021],
    [300, 0.021],
    [320, 0.022],
    [361.3, 0.155],
    [362.0, 0.078],
    [379.0, 0.024],
    [400.8, 0.034],
    [401.4, 0.830],
    [402.6, 0.145],
    [419, 0.071],
    [427.2, 0.105],
    [431.2, 3.650],
    [441.6, 0.133],
    [472, 0.095],
    [484.6, 0.298],
    [500.1, 0.057],
    [535.4, 0.234],
    [537.0, 0.554],
    [538.0, 1.111],
    [541.0, 0.921],
    [541.8, 3.350],
    [542.4, 1.195],
    [546.3, 0.241],
    [541.9, 3.906],
    [573.2, 0.032],
    [574.7, 0.216],
    [576.4, 0.273],
    [586.1, 0.124],
    [602.2, 0.043],
    [607, 0.238],
    [608.4, 0.875],
    [634, 0.029],
    [747, 0.023],
    [800, 0.021]
])

vs3 = keikoto[:,1] - v_offset
vs3 /= np.max(vs3)

plt.xlim(200, 800)

plt.xlabel("wavelength [nm]")
plt.ylabel("intensity (a.u.)")
plt.scatter(keikoto[:, 0] + offset, vs3)
plt.show()

# %%
chiso = np.array([
    [350, 3.03],
    [350.2, 0.939],
    [351.6, 0.972],
    [352, 2.141],
    [353, 6.703],
    [354, 9.115],
    [356, 0.107],
    [363.8, 0.431],
    [365.6, 0.180],
    [367.6, 1.675],
    [369.5, 0.370],
    [372.4, 4.824],
    [374.4, 0.276],
    [377.4, 6.846],
    [379.4, 0.102],
    [381, 0.122],
    [383.2, 0.159],
    [385.2, 0.274],
    [385.8, 0.430],
    [386.8, 0.622],
    [388.6, 0.259],
    [390, 0.545]
])

vs4 = chiso[:,1] - v_offset
vs4 /= np.max(vs4)

plt.xlabel("wavelength [nm]")
plt.ylabel("intensity (a.u.)")
plt.plot(chiso[:, 0] + offset, vs4, marker="o")
plt.show()
