# %%
import csv
import matplotlib.pyplot as plt

# %%
with open('1.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 1")
plt.legend()
plt.show()

# %%
with open('2.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 2")
plt.legend()
plt.show()

# %%
with open('3.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 3")
plt.legend()
plt.show()

# %%
with open('4.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 4")
plt.legend()
plt.show()

# %%
with open('5.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 5")
plt.legend()
plt.show()

# %%
with open('6.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 6")
plt.legend()
plt.show()

# %%
with open('7.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 7")
plt.legend()
plt.show()

# %%
with open('8.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 8")
plt.legend()
plt.show()

# %%
with open('9.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 9")
plt.legend()
plt.show()

# %%
with open('10.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 10")
plt.legend()
plt.show()

# %%
with open('11.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 11")
plt.legend()
plt.show()

# %%
with open('12.csv', 'r') as f:
    reader = csv.reader(f)
    header = next(reader)  # ヘッダーを読み飛ばしたい時
    i=0
    x1 = []
    y1 = []
    y2 = []
    for row in reader:
        i+=1
        if i>20 and len(row) == 3:
            x1.append(float(row[0]))
            y1.append(float(row[1]))
            y2.append(float(row[2]))
plt.plot(x1, y1, label = 'CH1')
plt.plot(x1, y2, label = 'CH2')
plt.title("condition 12")
plt.legend()
plt.show()
