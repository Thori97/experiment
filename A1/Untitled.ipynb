# %%
import numpy as np
import sympy as sym
import matplotlib.pyplot as plt

# %matplotlib inline
sym.init_printing()
from pylab import rcParams

rcParams['figure.figsize'] = 16,9
plt.rcParams["font.size"] = 18

# %%
# Vgs = 0
data1 = np.array([
    # Vgs[V], Vds[V], Id[A]
    [0, 0, 0], # Idのレンジは30mA
    #[0, 1.035, 2.8e-3],
    #[0, 2.041, 4.1e-3],
    #[0, 3.070, 4.6e-3],
    #[0, 4.05, 4.8e-3],
    #[0, 4.98, 4.9e-3], 
    # Idのレンジは10mA
    [0, 0.096, 0.30e-3],
    [0, 0.316, 0.99e-3],
    [0, 0.589, 1.65e-3],
    [0, 1.028, 2.65e-3],
    [0, 1.469, 3.4e-3],
    [0, 2.073, 4.1e-3],
    [0, 2.511, 4.38e-3],
    [0, 3.055, 4.57e-3],
    [0, 4.07, 4.69e-3],
    [0, 4.98, 4.75e-3], 
    [0, 5.98, 4.79e-3],
    [0, 6.96, 4.79e-3],
    [0, 10.06, 4.8e-3],
    [0, 13.06, 4.79e-3],
    [0, 17.00, 4.75e-3],
    [0, 19.91, 4.72e-3],
    
])


plt.scatter(data1[:, 1], data1[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs2 = 0.19 # V
data2 = np.array([
    # Idのレンジは10mA
    # Vgs[V], Vds[V], Id[A]
    [0.2, 0.116, 0.38e-3],
    [0.2, 0.280, 0.8e-3],
    [0.2, 0.592, 1.56e-3],
    [0.2, 0.997, 2.38e-3],
    [0.2, 1.509, 3.10e-3],
    [0.2, 2.004, 3.59e-3],
    [0.2, 2.509, 3.82e-3],
    [0.2, 3.015, 3.95e-3],
    [0.2, 4.03, 4.02e-3],
    [0.2, 5.04, 4.07e-3],
    [0.2, 6.01, 4.10e-3],
    [0.2, 7.02, 4.10e-3],
    [0.2, 10.00, 4.12e-3],
    [0.2, 13.08, 4.13e-3],
    [0.2, 17.04, 4.10e-3],
    [0.2, 20.01, 4.10e-3],
])

plt.scatter(data2[:, 1], data2[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs3 = 0.4 # V
data3 = np.array([
    # Idのレンジは10mA
    # Vgs[V], Vds[V], Id[A]
    [0.4, 0.004, 0],
    [0.4, 0.115, 0.32e-3],
    [0.4, 0.315, 0.8e-3],
    [0.4, 0.589, 1.42e-3],
    [0.4, 1.003, 2.18e-3],
    [0.4, 1.501, 2.8e-3],
    [0.4, 2.002, 3.15e-3],
    [0.4, 2.490, 3.3e-3],
    [0.4, 3.017, 3.4e-3],
    [0.4, 3.993, 3.46e-3],
    [0.4, 4.96, 3.5e-3],
    [0.4, 6.01, 3.5e-3],
    [0.4, 6.98, 3.52e-3],
    [0.4, 10.04, 3.55e-3],
    [0.4, 13.04, 3.55e-3],
    [0.4, 17.10, 3.55e-3],
    [0.4, 20.03, 3.52e-3]
])

plt.scatter(data3[:, 1], data3[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs4 = 0.6 # V
data4 = np.array([
    # Idのレンジは10mA
    # Vgs[V], Vds[V], Id[A]
    [0.6, 0.004, 0],
    [0.6, 0.106, 0.3e-3],
    [0.6, 0.299, 0.75e-3],
    [0.6, 0.641, 1.4e-3],
    [0.6, 1.000, 2.0e-3],
    [0.6, 1.534, 2.5e-3],
    [0.6, 2.007, 2.75e-3],
    [0.6, 2.520, 2.82e-3],
    [0.6, 2.956, 2.9e-3],
    [0.6, 3.992, 2.9e-3],
    [0.6, 5.03, 2.95e-3],
    [0.6, 6.01, 3.0e-3],
    [0.6, 6.99, 3.0e-3],
    [0.6, 10.01, 3.0e-3],
    [0.6, 12.91, 3.0e-3],
    [0.6, 17.07, 3.0e-3],
    [0.6, 20.01, 3.0e-3]
])

plt.scatter(data4[:, 1], data4[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs5 = 0.8 # V
data5 = np.array([
    # Idのレンジは3000uA
    # Vgs[V], Vds[V], Id[A]
    [0.8, 0, 0],
    [0.8, 0.091, 180e-6],
    [0.8, 0.300, 600e-6],
    [0.8, 0.602, 1150e-6],
    [0.8, 1.010, 1700e-6],
    [0.8, 1.497, 2100e-6],
    [0.8, 2.008, 2300e-6],
    [0.8, 2.494, 2360e-6],
    [0.8, 2.994, 2400e-6],
    [0.8, 4.01, 2440e-6],
    [0.8, 4.99, 2460e-6],
    [0.8, 6.07, 2470e-6],
    [0.8, 6.92, 2490e-6],
    [0.8, 9.89, 2500e-6],
    [0.8, 13.00, 2500e-6],
    [0.8, 17.06, 2510e-6],
    [0.8, 20.07, 2510e-6]
])

plt.scatter(data5[:, 1], data5[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs6 = 1.0 # V
data6 = np.array([
    # Idのレンジは3000uA
    # Vgs[V], Vds[V], Id[A]
    [1.0, 0.003, 0],
    [1.0, 0.094, 160e-6],
    [1.0, 0.303, 550e-6],
    [1.0, 0.565, 950e-6],
    [1.0, 0.994, 1440e-6],
    [1.0, 1.538, 1750e-6],
    [1.0, 1.984, 1840e-6],
    [1.0, 2.53, 1900e-6],
    [1.0, 2.973, 1920e-6],
    [1.0, 3.947, 1950e-6],
    [1.0, 4.99, 1960e-6],
    [1.0, 5.97, 1970e-6],
    [1.0, 7.03, 1980e-6],
    [1.0, 10.08, 2000e-6],
    [1.0, 12.94, 2000e-6],
    [1.0, 17.06, 2010e-6],
    [1.0, 20.07, 2010e-6]
])

plt.scatter(data6[:, 1], data6[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs7 = 1.2 # V
data7 = np.array([
    # Idのレンジは3000uA
    # Vgs[V], Vds[V], Id[A]
    [1.2, 0.003, 0],
    [1.2, 0.099, 150e-6],
    [1.2, 0.294, 460e-6],
    [1.2, 0.596, 850e-6],
    [1.2, 1.002, 1190e-6],
    [1.2, 1.533, 1370e-6],
    [1.2, 2.010, 1420e-6],
    [1.2, 2.475, 1450e-6],
    [1.2, 2.978, 1460e-6],
    [1.2, 3.99, 1490e-6],
    [1.2, 5.03, 1500e-6],
    [1.2, 6.01, 1510e-6],
    [1.2, 6.98, 1510e-6],
    [1.2, 10.06, 1520e-6],
    [1.2, 12.91, 1530e-6],
    [1.2, 17.14, 1540e-6],
    [1.2, 20.05, 1540e-6]
])

plt.scatter(data7[:, 1], data7[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs8 = 1.4 # V
data8 = np.array([
    # Idのレンジは3000uA
    # Vgs[V], Vds[V], Id[A]
    [1.4, 0.003, 0],
    [1.4, 0.103, 130e-6],
    [1.4, 0.316, 410e-6],
    [1.4, 0.611, 700e-6],
    [1.4, 1.032, 930e-6],
    [1.4, 1.494, 1020e-6],
    [1.4, 1.994, 1050e-6],
    [1.4, 2.463, 1060e-6],
    [1.4, 3.060, 1070e-6],
    [1.4, 4.01, 1090e-6],
    [1.4, 5.05, 1090e-6],
    [1.4, 5.94, 1100e-6],
    [1.4, 7.04, 1110e-6],
    [1.4, 10.13, 1120e-6],
    [1.4, 13.02, 1120e-6],
    [1.4, 17.06, 1130e-6],
    [1.4, 19.96, 1140e-6]
])

plt.scatter(data8[:, 1], data8[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs9 = 1.6 # V
data9 = np.array([
    # Idのレンジは3000uA
    # Vgs[V], Vds[V], Id[A]
    [1.6, 0.003, 0],
    [1.6, 0.090, 100e-6],
    [1.6, 0.305, 320e-6],
    [1.6, 0.595, 530e-6],
    [1.6, 0.999, 660e-6],
    [1.6, 1.475, 700e-6],
    [1.6, 1.994, 710e-6],
    [1.6, 2.496, 730e-6],
    [1.6, 3.000, 730e-6],
    [1.6, 3.936, 740e-6],
    [1.6, 5.03, 750e-6],
    [1.6, 6.05, 750e-6],
    [1.6, 6.97, 760e-6],
    [1.6, 10.01, 770e-6],
    [1.6, 13.07, 780e-6],
    [1.6, 16.99, 780e-6],
    [1.6, 20.04, 780e-6]
])

plt.scatter(data9[:, 1], data9[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs10 = 1.8 # V
data10 = np.array([
    # Idのレンジは3000uA
    # Vgs[V], Vds[V], Id[A]
    [1.8, 0.003, 0],
    [1.8, 0.104, 80e-6],
    [1.8, 0.298, 140e-6],
    [1.8, 0.574, 370e-6],
    [1.8, 1.024, 430e-6],
    [1.8, 1.531, 450e-6],
    [1.8, 2.004, 460e-6],
    [1.8, 2.476, 460e-6],
    [1.8, 3.076, 480e-6],
    [1.8, 3.956, 480e-6],
    [1.8, 5.02, 480e-6],
    [1.8, 6.03, 490e-6],
    [1.8, 6.97, 490e-6],
    [1.8, 10.02, 500e-6],
    [1.8, 12.96, 500e-6],
    [1.8, 17.09, 500e-6],
    [1.8, 20.14, 500e-6]
])

plt.scatter(data10[:, 1], data10[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
Vgs11 = 2.0 # V
data11 = np.array([
    # Idのレンジは300uA
    # Vgs[V], Vds[V], Id[A]
    [2.0, 0.003, 0],
    [2.0, 0.117, 81e-6],
    [2.0, 0.295, 165e-6],
    [2.0, 0.597, 224e-6],
    [2.0, 0.993, 239e-6],
    [2.0, 1.480, 245e-6],
    [2.0, 2.005, 250e-6],
    [2.0, 2.505, 252e-6],
    [2.0, 3.005, 254e-6],
    [2.0, 3.97, 257e-6],
    [2.0, 4.92, 259e-6],
    [2.0, 5.99, 262e-6],
    [2.0, 7.02, 264e-6],
    [2.0, 9.98, 267e-6],
    [2.0, 13.12, 270e-6],
    [2.0, 17.05, 272e-6],
    [2.0, 20.00, 274e-6]
])

plt.scatter(data10[:, 1], data10[:, 2] * 1e3)
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')

# %%
# %matplotlib notebook
plt.scatter(data1[:, 1], data1[:, 2] * 1e3)
plt.scatter(data2[:, 1], data2[:, 2] * 1e3)
plt.scatter(data3[:, 1], data3[:, 2] * 1e3)
plt.scatter(data4[:, 1], data4[:, 2] * 1e3)
plt.scatter(data5[:, 1], data5[:, 2] * 1e3)
plt.scatter(data6[:, 1], data6[:, 2] * 1e3)
plt.scatter(data7[:, 1], data7[:, 2] * 1e3)
plt.scatter(data8[:, 1], data8[:, 2] * 1e3)
plt.scatter(data9[:, 1], data9[:, 2] * 1e3)
plt.scatter(data10[:, 1], data10[:, 2] * 1e3)
plt.scatter(data11[:, 1], data11[:, 2] * 1e3)

plt.title("$V_{DS} - I_{D}$")
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')
plt.xlim(-0.1, 21)
plt.ylim(-0.1, 6.0)

def Id(Vds, Vo, Rl):
    return (Vo - Vds) / Rl

Vds = np.arange(0, 23, 0.1)

#plt.plot(Vds, Id(Vds, 10, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 2e3) * 1e3)
plt.plot(Vds, Id(Vds, 20, 2e3) * 1e3, label="$R_L=2k\Omega, V_0=20V$")
#plt.plot(Vds, Id(Vds, 30, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 10e3) * 1e3)
plt.plot(Vds, Id(Vds, 30, 10e3) * 1e3, label="$R_L=10k\Omega, V_0=30V$")
#plt.plot(Vds, Id(Vds, 10, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 20e3) * 1e3)

plt.plot(Vds, Id(Vds, 30, 2e3) * 1e3, label="$R_L=2k\Omega, V_0=30V$")
plt.plot(Vds, Id(Vds, 20, 10e3) * 1e3, label="$R_L=10k\Omega, V_0=20V$")
plt.legend()

# %%
 #%matplotlib notebook
plt.plot(data1[:, 1], data1[:, 2] * 1e3)
plt.plot(data2[:, 1], data2[:, 2] * 1e3)
plt.plot(data3[:, 1], data3[:, 2] * 1e3)
plt.plot(data4[:, 1], data4[:, 2] * 1e3)
plt.plot(data5[:, 1], data5[:, 2] * 1e3)
plt.plot(data6[:, 1], data6[:, 2] * 1e3)
plt.plot(data7[:, 1], data7[:, 2] * 1e3)
plt.plot(data8[:, 1], data8[:, 2] * 1e3)
plt.plot(data9[:, 1], data9[:, 2] * 1e3)
plt.plot(data10[:, 1], data10[:, 2] * 1e3)
plt.plot(data11[:, 1], data11[:, 2] * 1e3)

plt.title("$V_{DS} - I_{D}$")
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')
plt.xlim(-0.1, 21)
plt.ylim(-0.1,5.0)
plt.savefig("A1_3.png")

def Id(Vds, Vo, Rl):
    return (Vo - Vds) / Rl

Vds = np.arange(0, 23, 0.1)

#plt.plot(Vds, Id(Vds, 10, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 20e3) * 1e3)
# Out:
# <img src="data:image/png;base64,..." width="1152">
# <img src="data:image/png;base64,..." width="1152">

# %%
Rma = [4.4,1.7,0.6,0.2,0.1]
Rua = [4.66e3,6.73e3,2.74e3,0.876e3,297.7]
#3,10,30,100,300
Rv = [29.96e3,99.9e3,299.3e3,0.998e6,2.985e6]
data1 = np.array([
   # V[V], I[A], 電圧計の内部抵抗[Ω], 電流計の内部抵抗[Ω]
   [1.5, 8.8e-3, 29.96e3, 4.4],
   [1.2, 5.2e-3, 29.96e3, 4.4],
   [1.0, 3.2e-3, 29.96e3, 4.4],
   [0.8, 1.4e-3, 29.96e3, 4.4],
   [0.75, 1.0e-3, 29.96e3, 4.4],
   [0.75, 790e-6, 29.96e3, 876],
   [0.71, 600e-6, 29.96e3, 876],
   [0.65, 150e-6, 29.96e3, 876],
   [0.67, 200e-6, 29.96e3, 2.74e3],
])
data2 = np.array([
   # V[V], I[A], 電圧計の内部抵抗[Ω], 電流計の内部抵抗[Ω]
   [1.57, 9e-3, 29.96e3, 4.4],
   [1.20, 4.9e-3, 29.96e3, 4.4],
   [1.0, 3.0e-3, 29.96e3, 4.4],
   [0.8, 1.3e-3, 29.96e3, 4.4],
   [1.54, 900e-6, 29.96e3, 0.876e3],
   [1.23, 580e-6, 29.96e3, 0.876e3],
   [1.07, 420e-6, 29.96e3, 0.876e3],
   [0.85, 200e-6, 29.96e3, 0.876e3],
   [1.21, 200e-6, 29.96e3, 2.74e3],
   [0.98, 120e-6, 29.96e3, 2.74e3],
])

plt.title("A1.10(b)")
plt.yscale('log')
plt.xlabel("Voltage[V]")
plt.ylabel("Current[A]")
plt.scatter(data2[:, 0], data2[:, 1])
plt.show()

data2_fix = np.array([
   [d[0] - d[1] * d[3], d[1]]
for d in data2])

plt.title("V-I")
plt.yscale('log')
plt.xlabel("Voltage[V]")
plt.ylabel("Current[A]")
plt.plot(data2_fix[:, 0], data2_fix[:, 1])
plt.savefig("A1_2.png")
plt.show()

plt.title("A1.10(a)")
plt.yscale('log')
plt.xlabel("Voltage[V]")
plt.ylabel("Current[A]")
plt.scatter(data2[:, 0], data2[:, 1])
plt.show()

data1_fix = np.array([
   [d[0] - d[1] * d[3], d[1]]
for d in data1])

plt.title("A1.10(a) fixed")
plt.yscale('log')
plt.xlabel("Voltage[V]")
plt.ylabel("Current[A]")
plt.scatter(data1_fix[:, 0], data1_fix[:, 1])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = [
    [50, 420e-3, 912e-3, 13.8e-3],
    [100, 412e-3, 1.46, 6.16e-3],
    [200, 408e-3, 1.78, 2.84e-3],
    [500, 416e-3, 1.88, 1.06e-3],
    [1e3, 408e-3, 1.88, 520e-6],
    [2e3, 404e-3, 1.88, 260e-6],
    [5e3, 408e-3, 1.86, 102e-6],
    [10e3, 412e-3, 1.90, 50.4e-6],
    [20e3, 404e-3, 1.88, 25.2e-6],
    [50e3, 408e-3, 1.90, 10.2e-6],
    [100e3, 408e-3, 1.90, 4.88e-6],
    [1e6, 396e-3, 1.68, 432e-9],
    [2e6, 404e-3, 1.32, 176e-9],
]

data_withoutCs = [1e3,420e-3,980e-3,516e-6]
x = [d[0] for d in data]
y = [20*np.log(d[2]/d[1]) for d in data]
print(max(y))
plt.xscale('log')
plt.xlabel("frequency(Hz)")
plt.ylabel("gain(dB)")
plt.plot(x, y)
d = data_withoutCs
#plt.scatter(d[0], 20*np.log(d[2]/d[1]))
print(20*np.log(d[2]/d[1]))
plt.savefig("A1_5freq.png")
plt.show()
import math
y = [d[0]*d[3]*360 for d in data]
plt.xscale('log')
plt.plot(x, y)
plt.xlabel("frequency(Hz)")
plt.ylabel("Argment(deg)")
plt.savefig("A1_5arg.png")
plt.show()
# Out:
# 30.7668398150074
# 16.945957207744073

# %%
 #%matplotlib notebook
plt.plot(data1[:, 1], data1[:, 2] * 1e3)
plt.plot(data2[:, 1], data2[:, 2] * 1e3)
plt.plot(data3[:, 1], data3[:, 2] * 1e3)
plt.plot(data4[:, 1], data4[:, 2] * 1e3)
plt.plot(data5[:, 1], data5[:, 2] * 1e3)
plt.plot(data6[:, 1], data6[:, 2] * 1e3)
plt.plot(data7[:, 1], data7[:, 2] * 1e3)
plt.plot(data8[:, 1], data8[:, 2] * 1e3)
plt.plot(data9[:, 1], data9[:, 2] * 1e3)
plt.plot(data10[:, 1], data10[:, 2] * 1e3)
plt.plot(data11[:, 1], data11[:, 2] * 1e3)

plt.title("$V_{DS} - I_{D}$")
plt.xlabel("$V_{DS} [V]$")
plt.ylabel("$I_D [mA]$")
plt.grid(which='major',color='black',linestyle='-')
plt.grid(which='minor',color='black',linestyle='-')
plt.xlim(-0.1, 21)
plt.ylim(-0.1,5.0)
plt.savefig("A1_3.png")

def Id(Vds, Vo, Rl):
    return (Vo - Vds) / Rl

Vds = np.arange(0, 23, 0.1)

#plt.plot(Vds, Id(Vds, 10, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 1e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 2e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 10e3) * 1e3)
#plt.plot(Vds, Id(Vds, 10, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 15, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 20, 20e3) * 1e3)
#plt.plot(Vds, Id(Vds, 30, 20e3) * 1e3)
# Out:
# <img src="data:image/png;base64,..." width="1152">
# <img src="data:image/png;base64,..." width="1152">
